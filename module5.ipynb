# %%
tup=(10,20,304,50,40)
print(type(tup),tup)
# Out:
# <class 'tuple'> (10, 20, 304, 50, 40)

# %%
tup=(10,20,304,50,40)
tup.append(10) # it has no attribute like append
print(tup)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 tup=(10,20,304,50,40)
# ----> 2 tup.append(10) # it has no attribute like append
#       3 print(tup)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#mutability of list
lst=[1,2,3,4,5,56,6,7,8,0]
lst.append(100)
print(lst)
lst[0]=100
print(lst)

#immutabiity of tuple
tup=(10,20,304,50,40)
tup[0]=100
print(tup)
# Out:
# [1, 2, 3, 4, 5, 56, 6, 7, 8, 0, 100]
# [100, 2, 3, 4, 5, 56, 6, 7, 8, 0, 100]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       8 #immutabiity of tuple
#       9 tup=(10,20,304,50,40)
# ---> 10 tup[0]=100
#      11 print(tup)
#
# TypeError: 'tuple' object does not support item assignment

# %%
#set
set1={1,2,3,4,5,6}
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1={1,2,3,4,5,6}
print(type(set1))
# Out:
# <class 'set'>

# %%
set1={1,2,3,4,5,6}
set2={1,2,4,6,7}
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
set1={1,2,3,4,5,6}
set2={1,2,4,6,7}
print(set1.intersection(set2))
# Out:
# {1, 2, 4, 6}

# %%
set1={1,2,3,5,6,6,6,6,6}
if (10 in set1):
    print("10 is here")
else:
    print("none")

sum = 0
for element in set1:
    sum=sum+element
print(sum)
# Out:
# none
# 17

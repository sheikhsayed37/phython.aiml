# %%
print("hellow world")
# Out:
# hellow world

# %%
age=21
height=6.3
name="sayed"
passed_ssc=True
print(type(age),type(height),type(name),type(passed_ssc))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
name=input("what is your name")

print(name)

# %%
height = input("HEIGHT") #string hisebe nei
print(height,type(height)) #string type count kore manually
# Out:
# 23 <class 'str'>

# %%
height = input("HEIGHT") #string hisebe nei
height= int(height)
print(height,type(height)) #string type count kore manually

# %%
name= "Md sayed ali"
print(type(name),name)
# Out:
# <class 'str'> Md sayed ali

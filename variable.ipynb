# %%
height = input("HEIGHT") #string hisebe nei
height= int(height)
print(height,type(height)) #string type count kore manually
# Out:
# 21 <class 'int'>

# %%
height =int(input("HEIGHT")) #string hisebe nei

print(height,type(height)) #string type count kore manually
# Out:
# 23 <class 'int'>

# %%
height = float(input("HEIGHT")) #string hisebe nei

print(height,type(height)) #string type count kore manually
height =height+0.2
print(height)
# Out:
# 45.0 <class 'float'>
# 45.2

# %%
x=9;y=5
sum=x+y
sub=x-y
print(sum,sub)
# Out:
# 14 4

# %%
x=9;y=5
same_or_not=x==y
equal_or_not=x<=y
same_are=x!=y
NEW=(10>9)
print(same_or_not,equal_or_not,same_are)
print(NEW)
# Out:
# False False True
# True

# %%
x=1000;y=200;z=30
condition=(x>y) and (x>z)
print(condition)
# Out:
# True

# %%
x=1000;y=200;z=30
condition=((x+y)/2)+z-(x+5)
print(condition)
# Out:
# -375.0

# %%
x=1000;y=200;z=30
condition=(x>y) or (y<z)
print(condition)
# Out:
# True

# %%
num1=int(input())
num2=int(input())
 
 last_digit_of_num1=num1%10
 last_digit_of_num2=num2%10
sum= last_digit_of_num1+ last_digit_of_num2
print(sum)
# Out:
#   Cell In[18], line 4
#     last_digit_of_num1=num1/10
#     ^
# IndentationError: unexpected indent

# %%
x=int(input())
y=int(input()) #last digit er sum

last_digit_of_x=x%10
last_digit_of_y=y%10
sum = last_digit_of_x+last_digit_of_y
print(sum)
# Out:
# 4

# %%
#

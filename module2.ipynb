# %%
rainning= True

if rainning==True:
 print("need umbrella") 
else:
 print("no need ")
# Out:
# need umbrella

# %%
rainning= True
Muddy=False
if rainning==True:
 print("need umbrella")
 if Muddy == True:
    print("coution")
 else:
    print("sneakers use")
  
else:
 print("no need ")
# Out:
# need umbrella
# sneakers use

# %%
taka=349
if taka>500:
 print("canteen")
elif taka>400:
 print("order food")
elif taka>300:
 print("find discount and oder food")
elif taka>300:
 print("no need")

else:
  print("save money for futue")
# Out:
# find discount and oder food

# %%
taka=590
rainning=True
if taka>500 and rainning==False:
 print("go for travel")


else:
 print("save money for future")
# Out:
# save money for future

# %%
for i in range(12):
    print(i,"sayed")
# Out:
# 0 sayed
# 1 sayed
# 2 sayed
# 3 sayed
# 4 sayed
# 5 sayed
# 6 sayed
# 7 sayed
# 8 sayed
# 9 sayed
# 10 sayed
# 11 sayed

# %%
count=1
while count<10:
    print(count,"sayed")
    count= count+1
print(count)
# Out:
# 1 sayed
# 2 sayed
# 3 sayed
# 4 sayed
# 5 sayed
# 6 sayed
# 7 sayed
# 8 sayed
# 9 sayed
# 10

# %%
for i in range(1,10):
    print(i,"SAYED")
# Out:
# 1 SAYED
# 2 SAYED
# 3 SAYED
# 4 SAYED
# 5 SAYED
# 6 SAYED
# 7 SAYED
# 8 SAYED
# 9 SAYED

# %%
for i in range(1,10,3):
    print(i,"SAYED")
# Out:
# 1 SAYED
# 4 SAYED
# 7 SAYED

# %%
s

# %%
for i in range(1,10):
    for j in range(1,4):
     print(i,j)
# Out:
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
# 4 1
# 4 2
# 4 3
# 5 1
# 5 2
# 5 3
# 6 1
# 6 2
# 6 3
# 7 1
# 7 2
# 7 3
# 8 1
# 8 2
# 8 3
# 9 1
# 9 2
# 9 3

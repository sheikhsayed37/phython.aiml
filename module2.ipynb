# %%
rainning= True

if rainning==True:
 print("need umbrella") 
else:
 print("no need ")
# Out:
# need umbrella

# %%
rainning= True
Muddy=False
if rainning==True:
 print("need umbrella")
 if Muddy == True:
    print("coution")
 else:
    print("sneakers use")
  
else:
 print("no need ")
# Out:
# need umbrella
# sneakers use

# %%
taka=1000
if taka>500:
 print("canteen")
elif taka>400:
 print("order food")
elif taka>300:
 print("find discount and oder food")
elif taka>300:
 print("no need")

else:
  print("save money for futue")

# %%
prompt ="i am sheikh mohammed sayed ali"
print(prompt)
# Out:
# i am sheikh mohammed sayed ali

# %%
prompt =""" i am sheikh mohammed sayed ali ,

i am working in ai/ml"""

print(prompt)
# Out:
#  i am sheikh mohammed sayed ali ,
# i am working in ai/ml

# %%
message="""sheikh mohammed sayed ali..i am a student of international islamic universty
..i am not well because university makes my life folcol"""
print(message)
# Out:
# sheikh mohammed sayed ali..i am a student of international islamic universty
# ..i am not well because university makes my life folcol

# %% [markdown]
# ### indexing and slicing

# %% [markdown]
# string= "Sheikh Mohammed Sayed Ali"
# print(string[3])

# %%
string= "Sheikh Mohammed Sayed Ali"
print(string[19])
# Out:
# e

# %%
message="""sheikh mohammed sayed ali..i am a student of international islamic universty
..i am not well because university makes my life folcol"""
first_message=message[0:40]
print(first_message)
# Out:
# sheikh mohammed sayed ali..i am a studen

# %%
message="""sheikh mohammed sayed ali..i am a student of international islamic universty
..i am not well because university makes my life folcol"""
first_message=message[0:40:4]
print(first_message)
# Out:
# skomsdi au

# %%
message="""sheikh mohammed sayed ali..i am a student of international islamic universty
..i am not well because university makes my life folcol"""
first_message=message[0:27]
print(first_message)
print(first_message[-1])
print(first_message[-2])
print(first_message[-3])
print(first_message[-4])
# Out:
# sheikh mohammed sayed ali..
# .
# .
# i
# l

# %%
string="""Welcome to Phitron Ml course..This a full detailed course ,
it is ml"""

print(len(string))
update_version=string.lower()
print(update_version)
# Out:
# 68
# welcome to phitron ml course..this a full detailed course ,
# it is ml

# %%
string="""Welcome to Phitron Ml course , This a full detailed course, Phitron is ml"""


print(len(string))
update_version=string.lower()
print(update_version)
print("Phitron" in string)

#update_version er modde phitron ta koi number index e ache ta ber korar jonno

index=update_version.find("Phitron")
print(index)
# Out:
# 74
# welcome to phitron ml course,this a full detailed course ,phitron
# it is ml
# True
# -1

# %%
index1=string.find("Phitron")
print(index1)
# Out:
# 11

# %%
index2=update_version.count("phitron")
print(index2)
# Out:
# 1

# %%
string="""Welcome to Phitron Ml course , This a full detailed course, Phitron is ml"""


print(len(string))
update_version=string.lower()
print(update_version)
print("Phitron" in string)

#update_version er modde phitron ta koi number index e ache ta ber korar jonno

index=update_version.find("Phitron")
print(index)

#repalce korbo
index2=string.replace("Phitron","Phitron AI")
print(index2)
#count korbo
index3=string.count("Phitron")
print(index3)
# Out:
# 73
# welcome to phitron ml course , this a full detailed course, phitron is ml
# True
# -1
# Welcome to Phitron AI Ml course , This a full detailed course, Phitron AI is ml
# 2

# %%
string="""Welcome to Phitron Ml course , This a full detailed course, Phitron is ml"""


print(len(string))
update_version=string.lower()
print(update_version)
print("Phitron" in string)

#update_version er modde phitron ta koi number index e ache ta ber korar jonno

index=update_version.find("Phitron")
print(index)

#repalce korbo
index2=string.replace("Phitron","Phitron AI")
print(index2)
#count korbo
index3=string.count("Phitron")
print(index3)

#count a moloto lower case jeta korsi tare ignore kore dise 
update_version=string.replace("Phitron","Phitron AI")
print(update_version)
# Out:
# 73
# welcome to phitron ml course , this a full detailed course, phitron is ml
# True
# -1
# Welcome to Phitron AI Ml course , This a full detailed course, Phitron AI is ml
# 2
# Welcome to Phitron AI Ml course , This a full detailed course, Phitron AI is ml

# %%
question = "what is your name?"
index=question.split()
index1=question.split("-")

print(index)

print(index1)
# Out:
# ['what', 'is', 'your', 'name?']
# ['what is your name?']

# %%
question = "what is your name?"
index=question.split()
index1=question.split("-")

print(index)

print(index1)
#joinning
sentence="-".join(index)
print(sentence)
# Out:
# ['what', 'is', 'your', 'name?']
# ['what is your name?']
# what-is-your-name?

# %%
name="Sheikh Mohammed Sayed Ali"
age=22
id=45
print(f"My name is {name} and my age is {age} and my id is {id}")
# Out:
# My name is Sheikh Mohammed Sayed Ali and my age is 22 and my id is 45

# %%
#fomatted string

name="Sheikh Mohammed Sayed Ali"
age=22
id=45
index=f"My name is {name} and my age is {age} and my id is {id}"
print(index)
model_accuracy=0.87677
print(f"Model accuracy: {model_accuracy}")

print(f"Model accuracy: {model_accuracy:.2%}")

print(f"Model accuracy: {model_accuracy+10}")
# Out:
# My name is Sheikh Mohammed Sayed Ali and my age is 22 and my id is 45
# Model accuracy: 0.87677
# Model accuracy: 87.68%
# Model accuracy: 10.87677

# %%
name="Sheikh Mohammed Sayed Ali"
new=name[::-1] #reverse kore dise shortcut way
print(new)
# Out:
# ilA deyaS demmahoM hkiehS
